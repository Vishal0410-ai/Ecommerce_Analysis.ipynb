# %% [markdown]
# ### Analysis of a Ecommerce dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### Data type of each column

# %%
data.dtypes
# Out:
# Address              object
# Lot                  object
# AM or PM             object
# Browser Info         object
# Company              object
# Credit Card           int64
# CC Exp Date          object
# CC Security Code      int64
# CC Provider          object
# Email                object
# Job                  object
# IP Address           object
# Language             object
# Purchase Price      float64
# dtype: object

# %%
df=pd.read_csv("Ecommerce_dataset.csv")
data=df.drop("Unnamed: 0",axis=1)
data.head(2)
# Out:
#                                              Address    Lot AM or PM  \
# 0  16629 Pace Camp Apt. 448\r\nAlexisborough, NE ...  46 in       PM
# 1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
#
#                                         Browser Info  \
# 0  Opera/9.56.(X11; Linux x86_64; sl-SI) Presto/2...
# 1  Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
#
#                            Company       Credit Card CC Exp Date  \
# 0                  Martinez-Herman  6011929061123406       02/20
# 1  Fletcher, Richards and Whitaker  3337758169645356       11/18
#
#    CC Security Code   CC Provider               Email  \
# 0               900  JCB 16 digit   pdunlap@yahoo.com
# 1               561    Mastercard  anthony41@reed.com
#
#                                       Job       IP Address Language  \
# 0  Scientist, product/process development  149.146.147.205       el
# 1                       Drilling engineer     15.160.41.51       fr
#
# ...

# %%
data.describe()
# Out:
#         Credit Card  CC Security Code  Purchase Price
# count  1.000000e+04      10000.000000    10000.000000
# mean   2.341374e+15        907.217800       50.347302
# std    2.256103e+15       1589.693035       29.015836
# min    6.040186e+10          0.000000        0.000000
# 25%    3.056322e+13        280.000000       25.150000
# 50%    8.699942e+14        548.000000       50.505000
# 75%    4.492298e+15        816.000000       75.770000
# max    6.012000e+15       9993.000000       99.990000

# %% [markdown]
# ### Checking the Null Values

# %%
data.isnull().sum()
# Out:
# Address             0
# Lot                 0
# AM or PM            0
# Browser Info        0
# Company             0
# Credit Card         0
# CC Exp Date         0
# CC Security Code    0
# CC Provider         0
# Email               0
# Job                 0
# IP Address          0
# Language            0
# Purchase Price      0
# dtype: int64

# %% [markdown]
# ### Checking the number of rows and columns in the Dataset

# %%
data.shape
# Out:
# (10000, 14)

# %%
### only see the columns name
data.columns
# Out:
# Index(['Address', 'Lot', 'AM or PM', 'Browser Info', 'Company', 'Credit Card',
#        'CC Exp Date', 'CC Security Code', 'CC Provider', 'Email', 'Job',
#        'IP Address', 'Language', 'Purchase Price'],
#       dtype='object')

# %%
len(data.columns)
# Out:
# 14

# %%
### To see only purchase price
df['Purchase Price']
# Out:
# 0       98.14
# 1       70.73
# 2        0.95
# 3       78.04
# 4       77.82
#         ...
# 9995    82.21
# 9996    25.63
# 9997    83.98
# 9998    38.84
# 9999    67.59
# Name: Purchase Price, Length: 10000, dtype: float64

# %%
### Highest purchase price
df['Purchase Price'].max()
# Out:
# 99.99

# %%
### Lowest purchase price
df['Purchase Price'].min()
# Out:
# 0.0

# %%
### checking the std
df['Purchase Price'].std()
# Out:
# 29.015836309789048

# %%
var=list(df['Language'].unique())

# %%
var
# Out:
# ['el', 'fr', 'de', 'es', 'ru', 'pt', 'zh', 'en', 'it']

# %%
df.Language.value_counts()
# Out:
# de    1155
# ru    1155
# el    1137
# pt    1118
# en    1098
# fr    1097
# es    1095
# it    1086
# zh    1059
# Name: Language, dtype: int64

# %%
df[df["Language"]=="fr"]
# Out:
#       Unnamed: 0                                            Address    Lot  \
# 1              1  9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn
# 19            19              125 Hall Summit\r\nBoothton, IL 41721  99 CU
# 53            53            PSC 9431, Box 7059\r\nAPO AA 29285-1363  14 qD
# 76            76  49206 Campbell Port\r\nNorth Cliffordshire, HI...  71 iu
# 82            82  493 Smith Valleys Suite 004\r\nNew Madelinevil...  35 ls
# ...          ...                                                ...    ...
# 9941        9941         43757 Brown Lodge\r\nValerieberg, PR 88518  68 DG
# 9947        9947    32827 Carl Inlet\r\nSouth Nicole, NY 38081-6636  40 Dp
# 9951        9951              518 Brown Dam\r\nGarciaside, IN 33057  71 wq
# 9977        9977  02182 Keith Expressway\r\nEast Shannon, CT 205...  34 RL
# 9980        9980         6061 Dave Lights\r\nPhillipsview, UT 40500  25 Mv
#
#      AM or PM                                       Browser Info  \
# ...

# %% [markdown]
# ## to get engineer's informations
# ## str.contains will print wherever there is "engineer" in job
# ## returns a boolean array

# %%
data[data["Job"].str.contains("engineer",case=False)]
# Out:
#                                                 Address    Lot AM or PM  \
# 1     9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 3               7780 Julia Fords\r\nNew Stacy, WA 45798  36 vm       PM
# 50    41159 Michael Centers\r\nAdamsfort, RI 37108-6674  46 Ce       PM
# 55    27635 Maureen Bypass Apt. 883\r\nSandraview, S...  59 LJ       AM
# 60    7126 Katherine Squares\r\nPerkinsview, CO 9729...  63 qu       AM
# ...                                                 ...    ...      ...
# 9948  95544 Johnson Isle Suite 939\r\nMichaelberg, R...  91 bW       AM
# 9952          9991 Vaughn Hills\r\nRacheltown, PA 55409  36 KC       PM
# 9970            0060 Keith Stream\r\nWestport, CO 47097  11 nt       PM
# 9977  02182 Keith Expressway\r\nEast Shannon, CT 205...  34 RL       AM
# 9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY       AM
#
#                                            Browser Info  \
# ...

# %% [markdown]
# ### To find out total enigneers

# %%
len(data[data["Job"].str.contains("engineer",case=False)])
# Out:
# 984

# %% [markdown]
# ### showing full info of the person having this ip address

# %%
df[df['IP Address'] == "213.203.143.215"]
# Out:
#     Unnamed: 0                                            Address    Lot  \
# 50          50  41159 Michael Centers\r\nAdamsfort, RI 37108-6674  46 Ce
#
#    AM or PM                                       Browser Info  \
# 50       PM  Mozilla/5.0 (Windows 98; Win 9x 4.90; sl-SI; r...
#
#                         Company       Credit Card CC Exp Date  \
# 50  Wright, Williams and Mendez  4008586485908075       05/19
#
#     CC Security Code   CC Provider                      Email  \
# 50               945  JCB 16 digit  susanvalentine@obrien.org
#
#                     Job       IP Address Language  Purchase Price
# 50  Mechanical engineer  213.203.143.215       de           36.85

# %% [markdown]
# ### showing email of the person with this ip address

# %%
 
df["Email"][df['IP Address'] == "213.203.143.215"]
# Out:
# 50    susanvalentine@obrien.org
# Name: Email, dtype: object

# %% [markdown]
# ### People who use Mastercard credit card

# %%
data[data["CC Provider"]=="Mastercard"].head()
# Out:
#                                               Address    Lot AM or PM  \
# 1   9374 Jasmine Spurs Suite 508\r\nSouth John, TN...  28 rn       PM
# 18  461 Christopher Square\r\nWest Michaelchester,...  17 SB       PM
# 31                 USNS Alvarado\r\nFPO AA 27052-1231  26 Lh       PM
# 35  93392 Webb Gardens Apt. 220\r\nLaurabury, AR 9...  37 om       AM
# 41  779 Sydney Keys Apt. 119\r\nAnthonyside, NH 21...  21 lh       PM
#
#                                          Browser Info  \
# 1   Opera/8.93.(Windows 98; Win 9x 4.90; en-US) Pr...
# 18  Mozilla/5.0 (X11; Linux i686; rv:1.9.6.20) Gec...
# 31  Opera/8.84.(X11; Linux i686; sl-SI) Presto/2.9...
# 35  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10_7...
# 41  Mozilla/5.0 (Windows; U; Windows 98) AppleWebK...
#
#                             Company       Credit Card CC Exp Date  \
# 1   Fletcher, Richards and Whitaker  3337758169645356       11/18
# 18           Beard, Abbott and Pena  6011350184276270       12/22
# ...

# %%
len(data[data["CC Provider"]=="Mastercard"])
# Out:
# 816

# %% [markdown]
# ###  people having master card and made purchase of more than 80

# %%
 
df[(df["CC Provider"] == "Mastercard") & (df["Purchase Price"] > 80)]

# %% [markdown]
# ### top 5 e-mail providers

# %%
list1 = []
for each in df["Email"] :
    list1.append(each.split('@')[1])
    
    
df["email_provider"] = list1
df.head(1)



df["email_provider"].value_counts()


df["email_provider"].value_counts().head()
# Out:
# hotmail.com     1638
# yahoo.com       1616
# gmail.com       1605
# smith.com         42
# williams.com      37
# Name: email_provider, dtype: int64

# %% [markdown]
# ### How Many People have A Credit Card That Expires In 2025?

# %%
df[df['CC Exp Date'].str.contains("/25")]
# Out:
#       Unnamed: 0                                            Address    Lot  \
# 4              4  23012 Munoz Drive Suite 337\r\nNew Cynthia, TX...  20 IE
# 5              5  7502 Powell Mission Apt. 768\r\nTravisland, VA...  21 XT
# 7              7  260 Rachel Plains Suite 366\r\nCastroberg, WV ...  96 pG
# 13            13  118 Melton Via Suite 681\r\nAlexanderbury, FL ...  36 bu
# 15            15   31730 Chelsea Crest\r\nBlakemouth, CT 90395-0620  41 Cj
# ...          ...                                                ...    ...
# 9955        9955    66539 Potts Forge\r\nCartershire, AK 58271-5180  37 KB
# 9963        9963  3865 Davis Meadow Suite 915\r\nPort Stacieview...  11 fo
# 9993        9993  7555 Larson Locks Suite 229\r\nEllisburgh, MA ...  72 jg
# 9994        9994     6276 Rojas Hollow\r\nLake Louis, WY 56410-7837  93 Ex
# 9996        9996  832 Curtis Dam Suite 785\r\nNorth Edwardburgh,...  41 JY
#
#      AM or PM                                       Browser Info  \
# ...

# %%
df['Job'].value_counts()
# Out:
# Interior and spatial designer    31
# Lawyer                           30
# Social researcher                28
# Purchasing manager               27
# Designer, jewellery              27
#                                  ..
# Prison officer                    7
# Editor, film/video                6
# Actuary                           6
# Information systems manager       5
# Investment analyst                5
# Name: Job, Length: 623, dtype: int64
